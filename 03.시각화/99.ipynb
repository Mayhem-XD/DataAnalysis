# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

tips = sns.load_dataset('tips')
tips['tip_pct'] = (tips.tip / tips.total_bill * 100).round(2)
test = tips.pivot_table('tip_pct', 'day', aggfunc='mean').round(2)
test2 = tips.pivot_table('tip_pct', 'size', aggfunc='mean').round(2)

plt.bar(test.index, test.values.flatten())
# test.index, test.tip_pct
plt.title('요일별 팁 비율')
plt.xlabel('요일')
plt.ylabel('Tip percentage')
plt.show()

# %%
plt.bar(test2.index, test2.tip_pct)
plt.title('인원수별 팁 비율')
plt.xlabel('인원')
plt.ylabel('Tip percentage')
plt.show()

# %%
tips.pivot_table('tip_pct', 'day', aggfunc='mean').round(2)
# Out:
#       tip_pct
# day
# Thur    16.13
# Fri     16.99
# Sat     15.31
# Sun     16.69

# %% [markdown]
# II III IV I

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

ans = sns.load_dataset('anscombe')

# %%
d1 = ans[ans.dataset == 'I']
d2 = ans[ans.dataset == 'II']
d3 = ans[ans.dataset == 'III']
d4 = ans[ans.dataset == 'IV']

# %%
X,Y = ans.x,ans.y
plt.figure(figsize=(8,5))
plt.scatter(X,Y)
plt.plot([3,20],[4.5,13],'r')
plt.title('앤즈컴'),plt.grid()
plt.show()

# %%
X,Y = d1.x,d1.y
plt.figure(figsize=(4,2))
plt.scatter(X,Y)
plt.title('data1')
plt.show()

# %%
X,Y = d2.x,d2.y
plt.figure(figsize=(4,2))
plt.scatter(X,Y)
plt.title('data2')
plt.show()

# %%
X,Y = d3.x,d3.y
plt.figure(figsize=(4,2))
plt.scatter(X,Y)
plt.title('data2')
plt.show()

# %%
X,Y = d4.x,d4.y
plt.figure(figsize=(4,2))
plt.scatter(X,Y)
plt.title('data2')
plt.show()

# %%
for roman in ['I','II','III','IV']:
    ds = ans[ans.dataset == roman]
    plt.figure(figsize=(4,2))
    plt.scatter(ds.x,ds.y)
    plt.plot([3,20],[4.5,13],'r')
    plt.title(f'Dataset {roman}'),plt.grid()
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

filename = '../02.Pandas/data/서울시 자치구 년도별 CCTV 설치 현황_221231기준.csv'
colums = '구분,총계'.split(',')
cctv = pd.read_csv(filename, encoding='euc-kr',thousands=',')
cctv=cctv[colums]
cctv = cctv.rename(columns={'구분': '구별','총계': 'CCTV댓수'})
cctv.head()
# Out:
#     구별  CCTV댓수
# 0    계   91341
# 1  종로구    1980
# 2  중 구    2584
# 3  용산구    2847
# 4  성동구    4047

# %%
cctv.drop([cctv.index[0]],inplace=True)
cctv.head()
# Out:
#     구별  CCTV댓수
# 1  종로구    1980
# 2  중 구    2584
# 3  용산구    2847
# 4  성동구    4047
# 5  광진구    3480

# %%
# cctv.set_index('구별',inplace=True)
# plt.barh(cctv.index,cctv.CCTV댓수)
# plt.show()

# %%
plt.barh(cctv.구별,cctv.CCTV댓수)
plt.title('서울시 구별 cctv 댓수')
plt.show()

# %%
df1 = cctv.sort_values(by='구별',ascending=False)
plt.barh(df1.구별,df1.CCTV댓수)
plt.title('서울시 구별 cctv 댓수')
plt.show()

# %%
df2 = cctv.sort_values(by='CCTV댓수',ascending=True)
plt.barh(df2.구별,df2.CCTV댓수)
plt.title('서울시 구별 cctv 댓수')
plt.show()
