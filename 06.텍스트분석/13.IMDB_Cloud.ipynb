# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sw_wc = STOPWORDS.copy()
print(sw_wc)
# Out:
# {"there's", 'but', 'hers', "she's", 'doing', 'with', 'could', 'it', 'such', "weren't", "how's", 'k', 'of', 'other', 'same', "he'll", 'are', 'how', 'had', 'your', "she'll", 'not', "they'll", 'off', 'during', 'since', 'both', 'get', 'once', 'each', 'me', "they're", 'yourselves', 'i', 'was', "we've", 'my', 'any', 'because', 'these', 'until', 'an', "you'll", 'than', 'would', 'if', 'very', 'from', 'below', "won't", 'as', "hadn't", 'therefore', 'a', "don't", 'been', "you've", 'here', 'own', 'their', 'up', 'before', "why's", 'being', "shan't", 'again', 'can', 'his', 'whom', "here's", "you're", "can't", "he's", 'com', 'no', 'too', 'over', "they've", 'down', 'like', 'those', 'do', 'them', 'to', 'why', 'www', 'also', 'ours', 'some', 'should', 'this', 'there', "that's", 'does', "we'd", 'that', 'against', 'by', 'her', 'further', 'r', 'so', "we'll", 'into', "where's", 'else', 'shall', 'through', "who's", 'she', 'its', 'just', 'more', 'did', 'about', 'out', 'all', "she'd", "isn't", "let's", 'ought', "doesn't", 'or', 'at', "wouldn't", "he'd", "i've", 'between', 'yours', 'themselves', 'for', 'itself', 'most', "what's", 'theirs', 'while', 'am', 'otherwise', 'hence', "i'm", "didn't", 'nor', 'who', 'what', "mustn't", 'on', "shouldn't", "you'd", 'we', 'cannot', 'is', "we're", "when's", "hasn't", 'herself', 'you', 'yourself', 'he', 'they', 'only', 'ever', 'above', 'myself', 'have', 'however', "wasn't", "aren't", 'ourselves', "haven't", 'the', 'few', 'were', 'in', "i'll", 'our', 'under', 'and', 'him', "they'd", 'http', "i'd", "it's", 'where', "couldn't", 'has', 'when', 'be', 'then', 'which', 'having', 'after', 'himself'}

# %%
len(sw_wc)
# Out:
# 192

# %%
with open('data/test_review.txt') as f:
    text = f.read()

# %%
words = 'one,movie,film,Shawshank Redemption,Shawshank'.split(',')
for word in words:
    sw_wc.add(word)

# %%
wc = WordCloud(
    background_color = 'white',
    max_words = 4000,
    stopwords = sw_wc,
).generate(text)

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
count = 0
for key,val in wc.words_.items():
    print(f'{key}:\t{val}')
    count += 1
    if count >= 10:
        break
# Out:
# prison:	1.0
# time:	0.8786407766990292
# Redemption:	0.8604368932038835
# Andy:	0.8507281553398058
# story:	0.75
# hope:	0.6589805825242718
# good:	0.5716019417475728
# great:	0.5691747572815534
# Morgan Freeman:	0.5485436893203883
# character:	0.5473300970873787

# %%
mask = np.array(Image.open('data/sr_mask.png'))
plt.imshow(mask,cmap=plt.cm.gray,interpolation='bilinear')
plt.axis('off');

# %%
wc = WordCloud(
    background_color = 'black',
    max_words = 2000,
    stopwords = sw_wc,
    mask=mask
).generate(text)
plt.figure(figsize=(16,9))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
