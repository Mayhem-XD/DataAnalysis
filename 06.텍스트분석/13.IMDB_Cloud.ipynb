# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sw_wc = STOPWORDS.copy()
print(sw_wc)
# Out:
# {'get', "can't", 'should', 'were', 'has', "there's", 'their', 'few', 'such', 'here', 'or', 'if', 'there', 'have', 'because', 'further', 'is', "where's", 'not', 'just', 'they', "she'll", 'shall', 'theirs', 'cannot', 'why', 'however', "haven't", 'own', 'him', 'since', 'it', 'yourself', 'nor', 'also', "won't", 'before', 'are', 'up', 'yourselves', 'herself', 'otherwise', 'once', "weren't", 'had', 'and', 'do', 'am', 'did', 'by', "she's", 'its', 'itself', "she'd", 'yours', 'them', 'against', 'themselves', 'whom', 'else', 'myself', 'she', 'this', 'but', "i'm", 'ever', 'a', 'his', 'some', 'more', 'like', 'was', 'only', "you'd", 'to', 'no', "doesn't", 'under', 'our', "how's", 'between', 'in', "let's", "we'll", 'each', 'hers', "wasn't", 'when', "wouldn't", "they'll", 'then', "you'll", 'above', "couldn't", 'as', "we'd", 'me', "why's", "hadn't", "don't", "i'd", "you're", "isn't", 'an', "he'll", 'again', 'during', 'after', 'on', "we've", 'having', 'other', 'you', 'most', 'http', 'can', "they've", 'how', "here's", "they'd", 'r', 'very', 'ours', "that's", 'through', 'therefore', 'hence', 'which', 'while', 'so', 'of', 'below', "didn't", "aren't", 'over', 'down', 'same', 'any', "shan't", "it's", "shouldn't", 'those', 'your', 'does', 'until', 'my', 'being', 'from', 'himself', "they're", 'that', 'these', 'for', 'ought', 'with', "he's", "he'd", 'could', 'than', 'com', 'her', 'he', 'ourselves', 'what', 'doing', 'k', "mustn't", 'we', 'be', 'at', 'i', 'who', 'about', "what's", 'been', 'would', "i'll", 'out', 'all', "hasn't", "when's", "we're", 'too', 'into', "i've", 'off', "who's", 'both', 'where', "you've", 'the', 'www'}

# %%
len(sw_wc)
# Out:
# 192

# %%
with open('data/test_review.txt') as f:
    text = f.read()

# %%
sw_wc.add('one')
sw_wc.add('movie')
sw_wc.add('film')

# %%
wc = WordCloud(
    background_color = 'white',
    max_words = 4000,
    stopwords = sw_wc,
).generate(text)

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
count = 0
for key,val in wc.words_.items():
    print(f'{key}:\t{val}')
    count += 1
    if count >= 10:
        break
# Out:
# prison:	1.0
# time:	0.9640479360852197
# Andy:	0.933422103861518
# story:	0.8229027962716379
# Shawshank Redemption:	0.7869507323568575
# hope:	0.7230359520639148
# good:	0.6271637816245007
# great:	0.6245006657789614
# Morgan Freeman:	0.6018641810918774
# character:	0.6005326231691078
