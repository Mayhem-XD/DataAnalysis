# %% [markdown]
# ### 월드클라우드 - 어버이날 선물

# %%
import re, nltk
from konlpy.tag import Okt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
with open('data/어버이날 선물.txt') as f:
    text = f.read()

# %%
okt = Okt()
tokens = okt.nouns(text)            # 문장에서 명사 추출
tokens[:10]
# Out:
# ['어버이날', '선물', '추천', '탄생석', '골드', '카네이션', '추천', '카네이션', '자체', '전체']

# %%
new_tokens = []
for token in tokens:
    item = re.sub('[A-Za-z0-9]','',token)
    if item:
        new_tokens.append(item)

# %% [markdown]
# - 불용어 정리
#     - 아래 두 문장을 만족 할때 까지 반복

# %%
gift = nltk.Text(new_tokens, name='어버이날선물')
plt.figure(figsize=(12,6))
gift.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
stoptext = """
    선물 추천 어버이날 부모님 것 수 건강 제품 제 이 저 식품 가격 도움 요 참고 스 사용 활동 때 파트너 고민 수수료 위 구매 등 세트 생각 제공 거 기 분 상품 박스 정액 한번
    마음 이미지 존재 링크 일환 아래
"""
stop_words = stoptext.split()
new_tokens = [word for word in new_tokens if word not in stop_words]
new_tokens[:10]
# Out:
# ['탄생석', '골드', '카네이션', '카네이션', '자체', '전체', '도금', '완전', '금', '제작']

# %%
gift = nltk.Text(new_tokens, name='어버이날선물')
plt.figure(figsize=(12,6))
gift.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
stoptext = """
    선물 추천 어버이날 부모님 것 수 건강 제품 제 이 저 식품 가격 도움 요 참고 스 사용 활동 때 파트너 고민 수수료 위 구매 등 세트 생각 제공 거 기 분 상품 박스 정액 한번
    마음 이미지 존재 링크 일환 아래 정말 더 선택 향 기능 부담 지금 쿠팡 하나 관리 가지 양제 포스팅 답변 가장 채택 주문 준비 인기 브랜드 날 디자인 건 저희 채택 이번 정도 배송
    질문 이친 아버지 일 시간 나이 어머니 꼭 엄마
"""
stop_words = stoptext.split()
new_tokens = [word for word in new_tokens if word not in stop_words]
new_tokens[:10]
# Out:
# ['탄생석', '골드', '카네이션', '카네이션', '자체', '전체', '도금', '완전', '금', '제작']

# %%
gift = nltk.Text(new_tokens, name='어버이날선물')
plt.figure(figsize=(12,6))
gift.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
stoptext = """
    선물 추천 어버이날 부모님 것 수 건강 제품 제 이 저 식품 가격 도움 요 참고 스 사용 활동 때 파트너 고민 수수료 위 구매 등 세트 생각 제공 거 기 분 상품 박스 정액 한번
    마음 이미지 존재 링크 일환 아래 정말 더 선택 향 기능 부담 지금 쿠팡 하나 관리 가지 양제 포스팅 답변 가장 채택 주문 준비 인기 브랜드 날 디자인 건 저희 채택 이번 정도 배송
    질문 이친 아버지 일 시간 나이 어머니 꼭 엄마 정동 의미 발 제작 콘드 정보 도 중 할인 통해 평소 후기 보시 자 걸 사 직접 때문 좀 피 번 전 글 제일 다른 노블 관련 최고 드릴 바로
    통해 아빠 
"""
stop_words = stoptext.split()
new_tokens = [word for word in new_tokens if word not in stop_words]
new_tokens[:10]
# Out:
# ['탄생석', '골드', '카네이션', '카네이션', '자체', '전체', '도금', '완전', '금', '카네이션']

# %%
gift = nltk.Text(new_tokens, name='어버이날선물')
plt.figure(figsize=(12,6))
gift.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
stoptext = """
    선물 추천 어버이날 부모님 것 수 건강 제품 제 이 저 식품 가격 도움 요 참고 스 사용 활동 때 파트너 고민 수수료 위 구매 등 세트 생각 제공 거 기 분 상품 박스 정액 한번
    마음 이미지 존재 링크 일환 아래 정말 더 선택 향 기능 부담 지금 쿠팡 하나 관리 가지 양제 포스팅 답변 가장 채택 주문 준비 인기 브랜드 날 디자인 건 저희 채택 이번 정도 배송
    질문 이친 아버지 일 시간 나이 어머니 꼭 엄마 정동 의미 발 제작 콘드 정보 도 중 할인 통해 평소 후기 보시 자 걸 사 직접 때문 좀 피 번 전 글 제일 다른 노블 관련 최고 드릴 바로
    통해 아빠 경우 그 연골 용 가성 이벤트 검색 석고 해 조금 구성 효과 구 판매 고려 요즘
"""
stop_words = stoptext.split()
new_tokens = [word for word in new_tokens if word not in stop_words]
new_tokens[:10]
# Out:
# ['탄생석', '골드', '카네이션', '카네이션', '자체', '전체', '도금', '완전', '금', '카네이션']

# %%
gift = nltk.Text(new_tokens, name='어버이날선물')
plt.figure(figsize=(12,6))
gift.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
data = gift.vocab().most_common(5)
data
# Out:
# [('카네이션', 122), ('마사지', 122), ('용돈', 117), ('케이크', 97), ('꽃', 91)]

# %%
wc = WordCloud(
    background_color='white',
    random_state=2023,
    font_path='C:/Windows/Fonts/D2Coding-Ver1.3.2-20180524-all.ttc'
).generate_from_frequencies(dict(gift.vocab().most_common(300)))
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off');

# %%
wc = WordCloud(
    background_color='white',
    random_state=2023,
    font_path= 'C:/Users/YONSAI/AppData/Local/Microsoft/Windows/Fonts/NotoSansKR-Medium.otf', relative_scaling=0.2
).generate_from_frequencies(dict(gift.vocab().most_common(300)))
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off');

# %%
mask = np.array(Image.open('data/heart.jpg'))
from wordcloud import ImageColorGenerator
image_color = ImageColorGenerator(mask)

# %%
wc = WordCloud(
    background_color='white',
    random_state=2023,
    mask=mask,
    font_path= 'C:/Users/YONSAI/AppData/Local/Microsoft/Windows/Fonts/NotoSansKR-Medium.otf', relative_scaling=0.2
).generate_from_frequencies(dict(gift.vocab().most_common(300)))
plt.figure(figsize=(10,6))
plt.imshow(wc.recolor(color_func=image_color), interpolation='bilinear')
plt.axis('off');
