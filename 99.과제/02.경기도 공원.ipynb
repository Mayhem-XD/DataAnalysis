# %%
import json, folium, re
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/전국도시공원정보표준데이터.csv',encoding='euc-kr')
df1 = df1['공원명,소재지도로명주소,소재지지번주소,공원면적,제공기관명'.split(',')]
df1.columns = ['공원명','도로명주소','주소','면적','제공기관명']
df1.head(50).tail(10)
# Out:
#           공원명                   도로명주소                      주소      면적
# 40      독서당공원                     NaN      서울특별시 용산구 한남동 1-32   469.0  \
# 41       한남공원                     NaN      서울특별시 용산구 한남동 15-5   432.0
# 42  이태원어린이놀이터                     NaN   서울특별시 용산구 이태원동 190-11   278.0
# 43     한강대로공원                     NaN   서울특별시 용산구 한강로동 65-587   466.0
# 44     이태원부군당  서울특별시 용산구 녹사평대로40다길 33    서울특별시 용산구 이태원동 191-3  2020.0
# 45    이봉창역사공원                     NaN     서울특별시 용산구 효창동 286-7   484.4
# 46    신용산가로공원                     NaN   서울특별시 용산구 한강로2가 424-1  2410.0
# 47    한강로가로공원                     NaN  서울특별시 용산구 한강로3가 65-690  1076.3
# 48   한마음어린이공원                     NaN    서울특별시 용산구 용산동5가 30-4  2998.5
# 49      우정소공원                     NaN     서울특별시 용산구 효창동 287-2   806.1
#
#         제공기관명
# 40  서울특별시 용산구
# 41  서울특별시 용산구
# 42  서울특별시 용산구
# 43  서울특별시 용산구
# 44  서울특별시 용산구
# 45  서울특별시 용산구
# 46  서울특별시 용산구
# 47  서울특별시 용산구
# 48  서울특별시 용산구
# 49  서울특별시 용산구
